# %%
from IPython.display import clear_output
board=[1,2,3,4,5,6,7,8,9]
def display_board(board=[1,2,3,4,5,6,7,8,9]):
    # We are creating the board as the list as tuples are immuatable
    clear_output()
    print('    |    |    \n  {a} |  {b} | {c} \n    |    |    \n--------------\n    |    |    \n  {d} |  {e} | {f} \n    |    |    \n--------------\n    |    |    \n  {g} |  {h} | {i} \n    |    |   '.format(b=board[1],c=board[2],d=board[3],e=board[4],f=board[5],g=board[6],h=board[7],i=board[8],a=board[0]))

# %%
display_board()
# Out:
#     |    |
#   1 |  2 | 3
#     |    |
# --------------
#     |    |
#   4 |  5 | 6
#     |    |
# --------------
#     |    |
#   7 |  8 | 9
#     |    |

# %%
print('Welcome to Tic Tac Toe (developed by Sambhav Jain)\n\n') 
board=[1,2,3,4,5,6,7,8,9] 
player1_name=input('Please enter the name of the first player.\n') 
player2_name=input('Now, please enter the name of the second player.\n') 
clear_output() 
player1_symbol=input('{a}, please enter your symbol X or O. \n'.format( a=player1_name )) 
while(player1_symbol!='x' and player1_symbol!='X' and player1_symbol!='o' and player1_symbol!='O'):
    print('OOPS! You entered wrong choice. Please re-enter the symbol\n')
    player1_symbol=input('{a}, please enter your symbol X or O. \n'.format( a=player1_name ))

if player1_symbol=='x' or player1_symbol=='X':
    player1_symbol='X'
    player2_symbol='O' 
else:
        player1_symbol='O'
        player2_symbol='X'

print('{a} has symbol {b} \n\n'. format(a=player2_name, b=player2_symbol))
clear_output()
display_board()

win=False 
i=1 # stores the player number currently playing 
position1=False # indicates whether the position of the playr 1 is entered or not 
position2=False

while(win==False):
    if i==1:
        A=int(input('{}, please select the position number '.format(player1_name)))
        while(A not in [1,2,3,4,5,6,7,8,9] ):
            clear_output()
            print('{}, you entered wrong choice!! Reenter your choice'.format(player1_name))
            A=int(input('{}, please select the position number '.format(player1_name)))
            display_board()
            continue
            
        while(position1!=True):
            if board[A-1]!=A:
                clear_output()
                print('The place is occupied !!! Please select some other position')
                A=int(input('{}, please select the position number '.format(player1_name)))
                display_board()
            else:
                position1=True
                
        board[A-1]=player1_symbol
        i=2
        clear_output()
        display_board(board)
    else:
        A=int(input('{}, please select the position number '.format(player2_name)))
        while(A not in [1,2,3,4,5,6,7,8,9] ):
            clear_output()
            print('{}, you entered wrong choice!! Reenter your choice'.format(player2_name))
            A=int(input('{}, please select the position number '.format(player2_name)))
            display_board()
            continue
            
        while(position2!=True):
            if board[A-1]!=A:
                clear_output()
                print('The place is occupied !!! Please select some other position')
                A=int(input('{}, please select the position number '.format(player2_name)))
                display_board()
            else:
                position2=True
                
        board[A-1]=player2_symbol
        i=1
        clear_output()
        display_board(board)
    position1=False
    position2=False
    
    if(board[1]==board[2] and board[0]==board[1]):
        if(board[1]==player1_symbol):
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player1_name,player2_name))
            break
        else:
            
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player2_name,player1_name))
            break
            
    elif board[0]==board[3] and board[3]==board[6]:
         if(board[0]==player1_symbol):
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player1_name,player2_name))
            break
        
         else:
                
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player2_name,player1_name))
            break
    elif board[3]==board[4] and board[3]==board[5]:
         if(board[3]==player1_symbol):
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player1_name,player2_name))
            break
        
         else:
                
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player2_name,player1_name))
            break
    elif board[7]==board[8] and board[8]==board[6]:
        if(board[7]==player1_symbol):
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player1_name,player2_name))
            break
        else:
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player2_name,player1_name))
            break
    elif board[1]==board[4] and board[4]==board[7]:
        if(board[7]==player1_symbol):
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player1_name,player2_name))
            break
        else:
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player2_name,player1_name))
            break
    elif board[7]==board[8] and board[8]==board[6]:
        if(board[7]==player1_symbol):
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player1_name,player2_name))
            break
        else:
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player2_name,player1_name))
            break
    elif board[8]==board[5] and board[5]==board[2]:
        if(board[8]==player1_symbol):
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player1_name,player2_name))
            break
        else:
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player2_name,player1_name))
            break
    elif board[0]==board[4] and board[4]==board[8]:
        if(board[0]==player1_symbol):
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player1_name,player2_name))
            break
        else:
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player2_name,player1_name))
            break
    elif board[3]==board[5] and board[3]==board[7]:
        if(board[3]==player1_symbol):
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player1_name,player2_name))
            break

        else:
            win==True
            print('Hurray!!!! {} won the game \n {} lose the game'.format(player2_name,player1_name))
            break
    else:
        draw=0
        for item in [1,2,3,4,5,6,7,8,9]:
            if board[item-1]!=item:
                draw=draw+1
        if draw==9:
            print('The match is draw between {} and {}'.format(player1_name,player2_name))
            break
            win==True
# Out:
#     |    |
#   X |  2 | O
#     |    |
# --------------
#     |    |
#   X |  O | X
#     |    |
# --------------
#     |    |
#   X |  O | 9
#     |    |
# Hurray!!!! Sambhav won the game
#  Sahaj lose the game
